# %% [markdown]
# ## Megatutorial 3: Klassifikation von Daten

# %%
from pandas import read_csv

from sklearn.tree import DecisionTreeClassifier, plot_tree
from sklearn.neighbors import KNeighborsClassifier

from sklearn.metrics import f1_score, confusion_matrix, accuracy_score
from sklearn.metrics import recall_score, precision_score, classification_report

from sklearn.preprocessing import LabelEncoder
from matplotlib import pyplot as plt

# %% [markdown]
# ### Daten laden

# %%
data = read_csv(
    "../data/fake_profiles.csv",
    sep=",",
    decimal="."
)

# %% [markdown]
# ### Data Preprocessing

# %%
data.dropna(inplace=True)

# %%
feature = [
    'profile_pic', 'rel_num_numeric_char_username',
    'words_fullname', 'rel_num_numeric_char_fullname', 'name=username',
    'description_length', 'has_external_url', 'is_private'
]

target = ['is_fake']

# %%
X = data[feature]
y = data[target]

# %%
yes_no_encoder = LabelEncoder()

X.loc[:, "name=username"] = yes_no_encoder.fit_transform(X["name=username"])
X.loc[:, "profile_pic"] = yes_no_encoder.fit_transform(X["profile_pic"])
X.loc[:, "has_external_url"] = yes_no_encoder.fit_transform(X["has_external_url"])
X.loc[:, "is_private"] = yes_no_encoder.fit_transform(X["is_private"])

# %% [markdown]
# ### Decision Tree Machine Learning Model

# %%
tree_model = DecisionTreeClassifier(max_depth=5)

# %%
tree_model.fit(X, y)
# Out:
# DecisionTreeClassifier(max_depth=5)

# %%
predicitons = tree_model.predict(X)

# %%
plt.figure(figsize=(20,15))
plot_tree(tree_model)
plt.show()

# %%
data["predictions"] = predicitons

# %%
data
# Out:
#      Unnamed: 0 profile_pic  rel_num_numeric_char_username  words_fullname  \
# 0             0         yes                           0.27               0
# 1             1         yes                           0.00               2
# 2             2         yes                           0.10               2
# 3             3         yes                           0.00               1
# 4             4         yes                           0.00               2
# ..          ...         ...                            ...             ...
# 570         570         yes                           0.20               1
# 572         572         yes                           0.38               1
# 573         573         yes                           0.57               2
# 574         574         yes                           0.57               1
# 575         575         yes                           0.27               1
#
#      rel_num_numeric_char_fullname name=username  description_length  \
# 0                             0.00            no                  53
# 1                             0.00            no                  44
# 2                             0.00            no                   0
# 3                             0.00            no                  82
# 4                             0.00            no                   0
# ..                             ...           ...                 ...
# 570                           0.00            no                  28
# 572                           0.33            no                  21
# 573                           0.00            no                   0
# 574                           0.00            no                  11
# 575                           0.00            no                   0
#
#     has_external_url is_private  num_posts  num_followers  num_follows  \
# 0                 no         no         32         1000.0          955
# 1                 no         no        286         2740.0          533
# 2                 no        yes         13          159.0           98
# 3                 no         no        679          414.0          651
# 4                 no        yes          6          151.0          126
# ..               ...        ...        ...            ...          ...
# 570               no         no          0           15.0           64
# 572               no         no         44           66.0           75
# 573               no         no          4           96.0          339
# 574               no         no          0           57.0           73
# 575               no         no          2          150.0          487
#
#     is_fake predictions
# 0        no         yes
# 1        no          no
# 2        no          no
# 3        no          no
# 4        no          no
# ..      ...         ...
# 570     yes          no
# 572     yes         yes
# 573     yes         yes
# 574     yes         yes
# 575     yes         yes
#
# [556 rows x 14 columns]

# %% [markdown]
# ### Evaluation

# %%
confusion_matrix(y, predicitons)
# Out:
# array([[266,   8],
#        [ 38, 244]])

# %%
print(classification_report(y, predicitons))
# Out:
#               precision    recall  f1-score   support
#
#           no       0.88      0.97      0.92       274
#          yes       0.97      0.87      0.91       282
#
#     accuracy                           0.92       556
#    macro avg       0.92      0.92      0.92       556
# weighted avg       0.92      0.92      0.92       556

# %% [markdown]
# ### K Nearest Neighbour Machine Learning Model

# %%
knn_model = KNeighborsClassifier(n_neighbors=5)

# %%
knn_model.fit(X, y)
# Out:
# /workspaces/data-science/mlenv/lib/python3.12/site-packages/sklearn/neighbors/_classification.py:239: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return self._fit(X, y)
# KNeighborsClassifier()

# %%
knn_model.predict(X)
# Out:
# array(['no', 'no', 'no', 'no', 'no', 'no', 'no', 'no', 'no', 'no', 'no',
#        'no', 'no', 'no', 'no', 'no', 'no', 'no', 'no', 'no', 'no', 'no',
#        'no', 'no', 'no', 'no', 'no', 'no', 'no', 'no', 'no', 'no', 'no',
#        'no', 'yes', 'no', 'no', 'no', 'yes', 'no', 'no', 'no', 'no', 'no',
#        'no', 'no', 'no', 'no', 'no', 'no', 'no', 'no', 'no', 'no', 'no',
#        'no', 'no', 'no', 'no', 'no', 'no', 'no', 'no', 'no', 'no', 'no',
#        'no', 'no', 'no', 'no', 'no', 'no', 'no', 'no', 'no', 'no', 'no',
#        'no', 'no', 'no', 'no', 'no', 'no', 'no', 'no', 'no', 'no', 'no',
#        'no', 'no', 'no', 'no', 'no', 'no', 'no', 'no', 'no', 'no', 'no',
#        'no', 'no', 'no', 'no', 'no', 'no', 'no', 'no', 'no', 'no', 'no',
#        'no', 'no', 'no', 'no', 'no', 'yes', 'no', 'no', 'no', 'no', 'no',
#        'no', 'no', 'no', 'no', 'no', 'no', 'no', 'no', 'no', 'no', 'no',
#        'no', 'no', 'no', 'no', 'no', 'no', 'no', 'no', 'no', 'no', 'no',
#        'no', 'no', 'no', 'no', 'no', 'no', 'no', 'no', 'no', 'no', 'no',
#        'no', 'no', 'no', 'no', 'no', 'no', 'no', 'no', 'no', 'no', 'no',
#        'no', 'no', 'no', 'no', 'no', 'no', 'no', 'yes', 'no', 'no', 'no',
#        'no', 'no', 'no', 'no', 'no', 'no', 'no', 'no', 'no', 'no', 'no',
#        'no', 'no', 'no', 'no', 'no', 'no', 'no', 'no', 'no', 'no', 'no',
#        'no', 'no', 'no', 'no', 'no', 'no', 'no', 'no', 'no', 'no', 'no',
#        'no', 'no', 'no', 'no', 'no', 'no', 'no', 'no', 'no', 'no', 'no',
#        'no', 'no', 'no', 'no', 'no', 'no', 'no', 'no', 'no', 'no', 'no',
#        'no', 'yes', 'no', 'no', 'no', 'yes', 'yes', 'no', 'no', 'yes',
#        'no', 'no', 'yes', 'no', 'no', 'no', 'no', 'no', 'no', 'no', 'no',
#        'no', 'no', 'no', 'no', 'no', 'no', 'no', 'no', 'no', 'no', 'no',
#        'no', 'no', 'no', 'no', 'no', 'no', 'no', 'no', 'no', 'no', 'no',
#        'yes', 'yes', 'yes', 'no', 'no', 'yes', 'yes', 'yes', 'yes', 'yes',
#        'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes',
#        'yes', 'yes', 'yes', 'no', 'yes', 'yes', 'yes', 'yes', 'yes',
#        'yes', 'yes', 'yes', 'yes', 'yes', 'no', 'yes', 'yes', 'yes',
#        'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'no', 'yes', 'yes',
#        'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'no', 'yes', 'yes',
#        'yes', 'yes', 'no', 'yes', 'no', 'no', 'yes', 'yes', 'no', 'no',
#        'no', 'yes', 'yes', 'yes', 'yes', 'no', 'yes', 'yes', 'yes', 'yes',
#        'no', 'yes', 'yes', 'no', 'yes', 'yes', 'yes', 'no', 'yes', 'yes',
#        'yes', 'yes', 'yes', 'yes', 'no', 'yes', 'yes', 'yes', 'yes',
#        'yes', 'no', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes',
#        'yes', 'yes', 'yes', 'yes', 'no', 'yes', 'yes', 'yes', 'no', 'yes',
#        'yes', 'yes', 'no', 'yes', 'yes', 'yes', 'yes', 'yes', 'no', 'yes',
#        'no', 'no', 'yes', 'yes', 'yes', 'yes', 'no', 'yes', 'yes', 'yes',
#        'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes',
#        'no', 'no', 'yes', 'yes', 'no', 'yes', 'yes', 'yes', 'no', 'yes',
#        'no', 'no', 'no', 'yes', 'yes', 'no', 'yes', 'yes', 'no', 'no',
#        'no', 'yes', 'yes', 'yes', 'yes', 'no', 'yes', 'yes', 'no', 'yes',
#        'yes', 'yes', 'yes', 'no', 'yes', 'yes', 'no', 'yes', 'yes', 'yes',
#        'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes',
#        'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes',
#        'no', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes',
#        'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes',
#        'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes',
#        'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes',
#        'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'no', 'yes', 'yes',
#        'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes',
#        'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes',
#        'yes', 'yes', 'no', 'no', 'no', 'yes', 'yes', 'yes', 'yes', 'yes',
#        'no', 'yes', 'yes', 'yes', 'no', 'yes', 'yes', 'no', 'yes'],
#       dtype=object)

# %%
print(classification_report(y, knn_model.predict(X)))
# Out:
#               precision    recall  f1-score   support
#
#           no       0.85      0.97      0.90       274
#          yes       0.96      0.83      0.89       282
#
#     accuracy                           0.90       556
#    macro avg       0.90      0.90      0.90       556
# weighted avg       0.91      0.90      0.90       556

# %%
knn_model.score(X, y)
# Out:
# 0.8974820143884892

# %%
tree_model.score(X, y)
# Out:
# 0.9172661870503597
